# %%
# !pip install openai

# %%
import openai 
import os

openai.api_key = 'sk-wOunI05OFmNcFq9UM3R4T3BlbkFJy6tiZGgaUfRDmivY5HBx0'

def get_completion(prompt, model = "gpt-4-terbo"):
    messages = [{'role':"user","content": [rpmpt]}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        tempetature=0,
    )
    return response.choices[0].message["content"]

# %%
os.envirson['OPENAI_API_KEY'] = 'sk-wOunI05OFmNcFq9UM3R4T3BlbkFJy6tiZGgaUfRDmivY5HBx0'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 os.envirson['OPENAI_API_KEY'] = 'sk-wOunI05OFmNcFq9UM3R4T3BlbkFJy6tiZGgaUfRDmivY5HBx0'
#
# AttributeError: module 'os' has no attribute 'envirson'

# %%
from openai import OpenAI
client = OpenAI()

def get_completion(prompt, model="gpt-4-turbo"):
    competion = client.chat.completions.creat(
        model="gpt-3.5-turbo",
        messages = [
            {'role':"user","content": prompt}
        ]
        )

    return completion.choices[0].message.content
    get_completion('hello,gpt!')
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 from openai import OpenAI
# ----> 2 client = OpenAI()
#       4 def get_completion(prompt, model="gpt-4-turbo"):
#       5     competion = client.chat.completions.creat(
#       6         model="gpt-3.5-turbo",
#       7         messages = [
#       8             {'role':"user","content": prompt}
#       9         ]
#      10         )
#
# File c:\Users\r2com\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_client.py:98, in OpenAI.__init__(self, api_key, organization, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#      96     api_key = os.environ.get("OPENAI_API_KEY")
#      97 if api_key is None:
# ---> 98     raise OpenAIError(
# ...
